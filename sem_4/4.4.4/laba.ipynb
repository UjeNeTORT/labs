# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def LeastSquares(x_arr, y_arr): # returns [k, b, sigma_k, sigma b]
    v = x_arr
    u = y_arr

    N = len(v)

    mu = np.mean(u) # средее
    mv = np.mean(v)
    mv2 = np.mean([v_i**2 for v_i in v]) # средний квадрат
    mu2 = np.mean([u_i**2 for u_i in u])
    muv = np.mean ([u[i] * v[i] for i in range(len(u))]) # среднее от произведения
    k = (muv - mu * mv) / (mv2 - mv**2)
    b = mu - k * mv

    sigma_k = np.sqrt(1/(N-2) * ( (mu2 - mu**2)/(mv2 - mv**2) - k**2 ) )
    sigma_b = sigma_k * np.sqrt(mv2)

    return (k, b, sigma_k, sigma_b)

# %%
L = .1 * .001 # m
lambda_gren = 5600 * 1e-10
lambda_yell = 5800 * 1e-10


f = 50 * .001 # m

# %% [markdown]
# Натриевая лампа

# %%
ring_na_center = 162.6
rings_1 = [164.9, 167.4, 170.4, 171.4, 173.3, 174.1, 175.1]
rings_2 = [159.2, 157.1, 154.9, 153.3, 151.5, 150.7, 149.2]

# %%
# Исходные данные
data = [
    [159.2, 159.1, 159.3, 159.0],
    [157.1, 157.0, 157.2, 156.9],
    [154.9, 154.8, 155.0, 154.7],
    [153.3, 153.2, 153.4, 153.1],
    [151.5, 151.4, 151.6, 151.3],
    [150.7, 150.6, 150.8, 150.5],
    [149.2, 149.1, 149.3, 149.0]
]

print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.11180339887499266
# 0.11180339887498313
# 0.11180339887499266
# 0.11180339887499584
# 0.11180339887498313
# 0.11180339887499266

# %%
# Исходные данные
data = [
    [164.9, 165.1, 164.7, 164.8],
    [167.4, 167.2, 167.5, 167.3],
    [170.4, 170.3, 170.5, 170.2],
    [171.4, 171.3, 171.5, 171.2],
    [173.3, 173.2, 173.4, 173.1],
    [174.1, 174.0, 174.2, 173.9],
    [175.1, 175.0, 175.2, 174.9]
]

print(np.sqrt(np.std(data[0])**2 + 0.02**2))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.149248115565993
# 0.11180339887499267
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887499584
# 0.11180339887498313

# %%
rings = rings_2[::-1] + rings_1
rings
# Out:
# [149.2,
#  150.7,
#  151.5,
#  153.3,
#  154.9,
#  157.1,
#  159.2,
#  164.9,
#  167.4,
#  170.4,
#  171.4,
#  173.3,
#  174.1,
#  175.1]

# %%
delta_r = 159.1 - 158.4 # ширина кольца близкого к центру
delta_r = 166.2 - 165.7 # ширина кольца близкого к центру

# %%
lamb = 5780 * 1e-10

# %% [markdown]
# Ртутная лампа

# %%
ring_hg_center = 182.6
d_pyatno = 185.6 - 180.2

rings_green_top = [163.5, 165.1, 166.9, 169, 171.6, 180.5]
rings_green_low = [185.5, 190.5, 193.9, 196.4, 198.5, 200.2]

# %%
data = [
    [163.5, 163.4, 163.6, 163.3],
    [165.1, 165.0, 165.2, 164.9],
    [166.9, 166.8, 167.0, 166.7],
    [169.0, 168.9, 169.1, 168.8],
    [171.6, 171.5, 171.7, 171.4],
    [180.5, 180.4, 180.6, 180.3]
]

print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.11180339887498313
# 0.11180339887498313
# 0.11180339887499266
# 0.11180339887498313
# 0.11180339887498313
# 0.11180339887498313

# %%
# Исходные данные
data = [
    [185.5, 185.4, 185.6, 185.3],
    [190.5, 190.4, 190.6, 190.3],
    [193.9, 193.8, 194.0, 193.7],
    [196.4, 196.3, 196.5, 196.2],
    [198.5, 198.4, 198.6, 198.3],
    [200.2, 200.1, 200.3, 200.0]
]

# Создание 6 массивов
print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.11180339887498313
# 0.11180339887498313
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887498313
# 0.11180339887499266

# %%
d = [200.15 - 163.45, 198.45 - 165.05, 196.35 - 166.85, 193.85 - 168.95, 190.45 - 171.55, 185.45 - 180.45]
d_2 = [d**2 * .001**2 for d in d]
d = d[::-1]
d_2 = d_2[::-1]

# %%
sigma_d = np.sqrt(0.11**2 + 0.11**2)
sigma_d_2 = [2 * d * sigma_d *.001 for d in d]

# %%
[d * 1e6 for d in d_2]
# Out:
# [24.999999999999996,
#  357.2099999999991,
#  620.0100000000002,
#  870.2499999999999,
#  1115.5599999999986,
#  1346.8900000000012]

# %%
[d * 1e3 for d in sigma_d_2]
# Out:
# [np.float64(1.5556349186104048),
#  np.float64(5.8802999923473225),
#  np.float64(7.747061894679817),
#  np.float64(9.178246019801387),
#  np.float64(10.391641256317495),
#  np.float64(11.418360302600375)]

# %%
d = [200.15 - 163.45, 198.45 - 165.05, 196.35 - 166.85, 193.85 - 168.95, 190.45 - 171.55, 185.45 - 180.45]
d_2 = [d**2 * 1**2 for d in d]
d = d[::-1]
d_2 = d_2[::-1]
sigma_d = np.sqrt(0.11**2 + 0.11**2)
sigma_d_2 = [2 * d * sigma_d *1 for d in d]

# %%
m_values = np.array([1, 2, 3, 4, 5, 6])
z_m = np.array(d_2)
sigma_z = np.array(sigma_d_2)

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(m_values, z_m, yerr=sigma_z, fmt='.', capsize=8, label=r'')

# Linear fit (least squares approximation)
coeffs = np.polyfit(m_values, z_m, 1)  # Fit a straight line (degree = 1)
coeffs = LeastSquares(m_values, z_m)
linear_fit = np.poly1d(coeffs[:2])  # Create a polynomial function

# Generate smooth values for the fitted line
m_fit = np.linspace(min(m_values), max(m_values), 100)
z_fit = linear_fit(m_fit)
plt.plot(m_fit, z_fit, 'r')

# Labels and title
plt.xlabel(r'$i$')
plt.ylabel(r'$d_i^2$, мм^2')
plt.title("$d_i^2 = f(i)$")

# Grid and legend
plt.minorticks_on()
plt.grid(True, linestyle='--', alpha=0.7, which='major')
plt.grid(True, linestyle=':', alpha=0.7, which='minor')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3439/4107024360.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
k = coeffs[0] / 1e6 # si
L = 5461 * 1e-10 * 4 * f**2 / k
sigma_L = 5461 * 1e-10 * 4 * f**2 / k**2 * coeffs[2] /1e6
print(L * 1e6, sigma_L * 1e6)
# Out:
# 20.923967184616078 0.6489579776833974

# %%
rings_purple_low = [165.6, 167.4, 168.6, 170.6, 172.8, 175.8, 180.8]
rings_purple_top = [184.9, 189.8, 192.8, 194.9, 196.8, 198.4, 199.8]

# %%
# Исходные данные
data = [
    [165.6, 165.5, 165.7, 165.4],
    [167.4, 167.3, 167.5, 167.2],
    [168.6, 168.5, 168.7, 168.4],
    [170.6, 170.5, 170.7, 170.4],
    [172.8, 172.7, 172.9, 172.6],
    [175.8, 175.7, 175.9, 175.6],
    [180.8, 180.7, 180.9, 180.6]
]

print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
print(np.std(data[6]))
# Out:
# 0.11180339887498313
# 0.11180339887499266
# 0.11180339887498313
# 0.11180339887498313
# 0.11180339887499584
# 0.11180339887499584
# 0.11180339887499584

# %%
rings_brown_low = [166.4, 169.4, 170.9, 172, 174.2, 179.8]
rings_brown_top = [185.2, 191.2, 193.4, 194.4, 196.2, 197.1]

# %%
# Исходные данные
data = [
    [166.4, 166.3, 166.5, 166.2],
    [169.4, 169.3, 169.5, 169.2],
    [170.9, 170.8, 171.0, 170.7],
    [172.0, 171.9, 172.1, 171.8],
    [174.2, 174.1, 174.3, 174.0],
    [179.8, 179.7, 179.9, 179.6]
]

print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887498313
# 0.11180339887499266
# 0.11180339887499584

# %%
d = [199.75 - 165.55, 198.35 - 167.35, 196.75 - 168.55, 194.85 - 170.55, 192.75 -172.75, 189.75 - 175.75, 184.85 - 180.75]
d_2 = [d**2 * 1**2 for d in d]
d = d[::-1]
d_2 = d_2[::-1]
sigma_d = np.sqrt(0.11**2 + 0.11**2)
sigma_d_2 = [2 * d * sigma_d *1**2 for d in d]

# %%
m_values = np.array([1, 2, 3, 4, 5, 6, 7])
z_m = np.array(d_2)
sigma_z = np.array(sigma_d_2)

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(m_values, z_m, yerr=sigma_z, fmt='.', capsize=4, label=r'')

# Linear fit (least squares approximation)
coeffs = np.polyfit(m_values, z_m, 1)  # Fit a straight line (degree = 1)
coeffs = LeastSquares(m_values, z_m)
linear_fit = np.poly1d(coeffs[:2])  # Create a polynomial function

# Generate smooth values for the fitted line
m_fit = np.linspace(min(m_values), max(m_values), 100)
z_fit = linear_fit(m_fit)
plt.plot(m_fit, z_fit, 'r')

# Labels and title
plt.xlabel(r'$i$')
plt.ylabel(r'$d_i^2$, мм^2')
plt.title("$d_i^2 = f(i)$")

# Grid and legend
plt.minorticks_on()
plt.grid(True, linestyle='--', alpha=0.7, which='major')
plt.grid(True, linestyle=':', alpha=0.7, which='minor')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3439/3665582497.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
k = coeffs[0] / 1e6 # si
L = 5461 * 1e-10 * 4 * f**2 / k
sigma_L = 5461 * 1e-10 * 4 * f**2 / k**2 * coeffs[2] /1e6
print(L * 1e6, sigma_L * 1e6)
# Out:
# 28.40187007892299 0.26991486218386107

# %%
# Исходные данные
data = [
    [185.2, 185.1, 185.3, 185.0],
    [191.2, 191.1, 191.3, 191.0],
    [193.4, 193.3, 193.5, 193.2],
    [194.4, 194.3, 194.5, 194.2],
    [196.2, 196.1, 196.3, 196.0],
    [197.1, 197.0, 197.2, 196.9]
]

print(np.std(data[0]))
print(np.std(data[1]))
print(np.std(data[2]))
print(np.std(data[3]))
print(np.std(data[4]))
print(np.std(data[5]))
# Out:
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887499266
# 0.11180339887498313

# %%
d = [197.05 - 166.35, 196.15 - 169.35, 194.35 - 170.85, 193.35 - 171.95, 191.15 - 174.15, 185.15 - 179.75]
d_2 = [d**2 * 1**2 for d in d]
d = d[::-1]
d_2 = d_2[::-1]
sigma_d = np.sqrt(0.11**2 + 0.11**2)
sigma_d_2 = [2 * d * sigma_d *1**2 for d in d]

# %%
m_values = np.array([1, 2, 3, 4, 5, 6])
z_m = np.array(d_2)
sigma_z = np.array(sigma_d_2)

# Plotting
plt.figure(figsize=(8, 5))
plt.errorbar(m_values, z_m, yerr=sigma_z, fmt='.', capsize=8)

# Linear fit (least squares approximation)
coeffs = np.polyfit(m_values, z_m, 1)  # Fit a straight line (degree = 1)
coeffs = LeastSquares(m_values, z_m)
linear_fit = np.poly1d(coeffs[:2])  # Create a polynomial function

# Generate smooth values for the fitted line
m_fit = np.linspace(min(m_values), max(m_values), 100)
z_fit = linear_fit(m_fit)
plt.plot(m_fit, z_fit, 'r')

# Labels and title
plt.xlabel(r'$i$')
plt.ylabel(r'$d_i^2$, мм^2')
plt.title("$d_i^2 = f(i)$")

# Grid and legend
plt.minorticks_on()
plt.grid(True, linestyle='--', alpha=0.7, which='major')
plt.grid(True, linestyle=':', alpha=0.7, which='minor')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3439/1272312249.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
k = coeffs[0] / 1e6 # si
L = 5461 * 1e-10 * 4 * f**2 / k
sigma_L = 5461 * 1e-10 * 4 * f**2 / k**2 * coeffs[2] /1e6
print(L * 1e6, sigma_L * 1e6)
# Out:
# 32.130765584181944 2.094538292889331
